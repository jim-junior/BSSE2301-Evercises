# %% [markdown]
# # Pandas Analysis
#
# **Supported File Formats**
#
# - CSV
# - BigQuery
# - Excel
# - JSON
# - Archives

# %%
import pandas as pd

df = pd.read_csv("data/mine.csv")

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# Fetching head elements

print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
print(df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
pd.options.display.max_rows = 100

print(df.tail(100))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 69        300    108       143    1500.2
# 70        150     97       129    1115.0
# 71         60    109       153     387.6
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 74         45    114       146     304.0
# 75         90     98       125     563.2
# 76         45    105       134     251.0
# 77         45    110       141     300.0
# 78        120    100       130     500.4
# 79        270    100       131    1729.0
# 80         30    159       182     319.2
# 81         45    149       169     344.0
# 82         30    103       139     151.1
# 83        120    100       130     500.0
# 84         45    100       120     225.3
# 85         30    151       170     300.0
# 86         45    102       136     234.0
# 87        120    100       157    1000.1
# 88         45    129       103     242.0
# 89         20     83       107      50.3
# 90        180    101       127     600.1
# ...

# %%
crimes = pd.read_csv("data/crimes.csv")
print(crimes.to_string())
# Out:
#     Unnamed: 0                                    Unnamed: 1 REPORTED CASES           Unnamed: 3        Unnamed: 4            Unnamed: 5                 PERFOMANCE              Unnamed: 7             Unnamed: 8       Unnamed: 9             Unnamed: 10 PERSONS TAKEN TO COURT  Unnamed: 12   Unnamed: 13    Unnamed: 14        Unnamed: 15  Unnamed: 16   Unnamed: 17    Unnamed: 18 Unnamed: 19 Unnamed: 20     Unnamed: 21 SENTENCES IMPOSED BY COURTS  Unnamed: 23   Unnamed: 24    Unnamed: 25 Unnamed: 26 Unnamed: 27           Unnamed: 28 Unnamed: 29 Unnamed: 30              Unnamed: 31       Unnamed: 32  Unnamed: 33   Unnamed: 34    Unnamed: 35             Unnamed: 36     Unnamed: 37
# ...

# %% [markdown]
# # Data Analysis
#
# ### Data Preparation
# - Null Values, wrong formats, incorrect formats, duplicates, wrong data
